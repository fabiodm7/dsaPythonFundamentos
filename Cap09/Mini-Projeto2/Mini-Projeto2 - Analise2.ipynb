# %% [markdown]
# # <font color='blue'>Data Science Academy - Python Fundamentos - Capítulo 9</font>
#
# ## Download: http://github.com/dsacademybr
#
# ## Mini-Projeto 2 - Análise Exploratória em Conjunto de Dados do Kaggle
#
# ## Análise 2

# %%
# Imports
import os
import subprocess
import stat
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
sns.set(style = "white")
# %matplotlib inline

# %%
# Dataset
clean_data_path = "dataset/autos.csv"
df = pd.read_csv(clean_data_path,encoding = "latin-1")
df.columns.values
# Out:
# array(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'postalCode', 'lastSeen',
#        'yearOfCreation', 'yearCrawled', 'monthOfCreation', 'monthCrawled',
#        'NoOfDaysOnline', 'NoOfHrsOnline', 'yearsOld', 'monthsOld'],
#       dtype=object)

# %% [markdown]
# ## Número de veículos pertencentes a cada marca

# %%
# Crie um Plot que mostre o número de veículos pertencentes a cada marca
sns.set_style("whitegrid")
graf = sns.catplot(data=df,y='brand',kind='count',palette='Reds_r',height=15)
graf.set_ylabels('Marca')
graf.set_xlabels('Número de veículos')
graf.ax.set_title('Número de veículos por marca')
# Out:
# Text(0.5, 1.0, 'Número de veículos por marca')

# %%
# Salvando o plot
g.savefig(("plots/Analise2/brand-vehicleCount.png"))

# %% [markdown]
# ## Preço médio dos veículos com base no tipo de veículo, bem como no tipo de caixa de câmbio

# %%
# Crie um Plot com o Preço médio dos veículos com base no tipo de veículo, bem como no tipo de caixa de câmbio
sns.set_style("whitegrid")
fig, ax = plt.subplots(figsize=(10,5))
cores = ["#00e600", "#ff8c1a","#a180cc"]
graf = sns.barplot(data=df,x='vehicleType',y='price',hue='gearbox',palette=cores)
graf.yaxis.set_label_text('Média de preço')
graf.xaxis.set_label_text('Tipo de veículo')
graf.set_title('Preço médio dos veículos por tipo de veículo e tipo de caixa de câmbio')
# Out:
# Text(0.5, 1.0, 'Preço médio dos veículos por tipo de veículo e tipo de caixa de câmbio')

# %%
# Salvando o plot
fig.savefig("plots/Analise2/vehicletype-gearbox-price.png")

# %% [markdown]
# # Fim

# %% [markdown]
# ### Obrigado
#
# ### Visite o Blog da Data Science Academy - <a href="http://blog.dsacademy.com.br">Blog DSA</a>
